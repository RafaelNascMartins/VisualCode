# %% [markdown]
# Arquivo IPYNB - Para dados (Você)

# %%
print("Hello World")
# Out:
# Hello World

# %%
conteiner = []


if conteiner == []:
    print("Conteiner is empty")
else:    print("Conteiner is not empty")
# Out:
# Conteiner is empty
